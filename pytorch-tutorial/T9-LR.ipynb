# %%
x = torch.tensor([1.0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e289f55f4cc> in <module>()
# ----> 1 x = torch.tensor([1.0])
#
# NameError: name 'torch' is not defined

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %%
X = torch.randn(100, 1) * 10
y = X + 3*torch.randn(100, 1)
plt.plot(X.numpy(), y.numpy(), 'o')
plt.ylabel('y')
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
class LR(nn.Module):
    def __init__(self, input_size, output_size):
      super().__init__()
      self.linear = nn.Linear(input_size, output_size)
      
    def forward(self, x):
      pred = self.linear(x)
      return pred

# %%
torch.manual_seed(1)
model = LR(1, 1)
print(model)
# Out:
# LR(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
[w, b] = model.parameters()
def get_params():
  return (w[0][0].item(),b[0].item())

# %%
def plot_fit(title):
  plt.title = title
  w1, b1 = get_params()
  x1 = np.array([-30,30])
  y1 = w1*x1 + b1
  plt.plot(x1, y1, 'r')
  plt.scatter(X, y)
  plt.show()

# %%
plot_fit('Inital model')

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001)

# %%
epochs = 100
losses = []
for i in range(epochs):
  y_pred = model.forward(X)
  loss = criterion(y_pred, y)
  print('epoch:   ', i, "loss, ", loss.item())
  
  losses.append(loss.item())
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
# Out:
# epoch:    0 loss,  29.3394832611084
# epoch:    1 loss,  20.76228904724121
# epoch:    2 loss,  15.531102180480957
# epoch:    3 loss,  12.340353965759277
# epoch:    4 loss,  10.393896102905273
# epoch:    5 loss,  9.20622444152832
# epoch:    6 loss,  8.481276512145996
# epoch:    7 loss,  8.038503646850586
# epoch:    8 loss,  7.76780891418457
# epoch:    9 loss,  7.602051734924316
# epoch:    10 loss,  7.500290870666504
# epoch:    11 loss,  7.437557697296143
# epoch:    12 loss,  7.398626804351807
# epoch:    13 loss,  7.374213695526123
# epoch:    14 loss,  7.358656406402588
# epoch:    15 loss,  7.348501682281494
# epoch:    16 loss,  7.341644763946533
# epoch:    17 loss,  7.336801052093506
# epoch:    18 loss,  7.333188533782959
# epoch:    19 loss,  7.330327987670898
# epoch:    20 loss,  7.327929973602295
# epoch:    21 loss,  7.325815677642822
# epoch:    22 loss,  7.323877811431885
# epoch:    23 loss,  7.322049140930176
# epoch:    24 loss,  7.3202900886535645
# epoch:    25 loss,  7.318576335906982
# epoch:    26 loss,  7.316892623901367
# epoch:    27 loss,  7.315229415893555
# epoch:    28 loss,  7.313581466674805
# epoch:    29 loss,  7.31194543838501
# epoch:    30 loss,  7.310319423675537
# epoch:    31 loss,  7.308701515197754
# epoch:    32 loss,  7.307090759277344
# epoch:    33 loss,  7.305487155914307
# epoch:    34 loss,  7.303890705108643
# epoch:    35 loss,  7.302300930023193
# epoch:    36 loss,  7.300717353820801
# epoch:    37 loss,  7.299140453338623
# epoch:    38 loss,  7.297569751739502
# epoch:    39 loss,  7.296005725860596
# epoch:    40 loss,  7.294447422027588
# epoch:    41 loss,  7.2928948402404785
# epoch:    42 loss,  7.291348934173584
# epoch:    43 loss,  7.289809226989746
# epoch:    44 loss,  7.288275718688965
# epoch:    45 loss,  7.286747932434082
# epoch:    46 loss,  7.285226345062256
# epoch:    47 loss,  7.2837114334106445
# epoch:    48 loss,  7.282201290130615
# epoch:    49 loss,  7.280697822570801
# epoch:    50 loss,  7.279200553894043
# epoch:    51 loss,  7.277709007263184
# epoch:    52 loss,  7.276223659515381
# epoch:    53 loss,  7.274743556976318
# epoch:    54 loss,  7.2732696533203125
# epoch:    55 loss,  7.271800994873047
# epoch:    56 loss,  7.270338535308838
# epoch:    57 loss,  7.2688822746276855
# epoch:    58 loss,  7.267431735992432
# epoch:    59 loss,  7.265986919403076
# epoch:    60 loss,  7.264547348022461
# epoch:    61 loss,  7.263113975524902
# epoch:    62 loss,  7.261685848236084
# epoch:    63 loss,  7.260263919830322
# epoch:    64 loss,  7.258847713470459
# epoch:    65 loss,  7.257436752319336
# epoch:    66 loss,  7.256030559539795
# epoch:    67 loss,  7.254631519317627
# epoch:    68 loss,  7.253237247467041
# epoch:    69 loss,  7.251848220825195
# epoch:    70 loss,  7.250465393066406
# epoch:    71 loss,  7.249087810516357
# epoch:    72 loss,  7.247715473175049
# epoch:    73 loss,  7.246348857879639
# epoch:    74 loss,  7.244987487792969
# epoch:    75 loss,  7.243631362915039
# epoch:    76 loss,  7.24228048324585
# epoch:    77 loss,  7.240935325622559
# epoch:    78 loss,  7.239595413208008
# epoch:    79 loss,  7.238260746002197
# epoch:    80 loss,  7.236931324005127
# epoch:    81 loss,  7.235607624053955
# epoch:    82 loss,  7.234288692474365
# epoch:    83 loss,  7.232975006103516
# epoch:    84 loss,  7.2316670417785645
# epoch:    85 loss,  7.230363368988037
# epoch:    86 loss,  7.229065418243408
# epoch:    87 loss,  7.227772235870361
# epoch:    88 loss,  7.226484775543213
# epoch:    89 loss,  7.2252020835876465
# epoch:    90 loss,  7.22392463684082
# epoch:    91 loss,  7.222651958465576
# epoch:    92 loss,  7.221384525299072
# epoch:    93 loss,  7.220122337341309
# epoch:    94 loss,  7.218864917755127
# epoch:    95 loss,  7.217612266540527
# epoch:    96 loss,  7.216364860534668
# epoch:    97 loss,  7.215122222900391
# epoch:    98 loss,  7.2138848304748535
# epoch:    99 loss,  7.212652206420898

# %%
plt.plot(range(epochs), losses)
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
plot_fit("Trained Model")
